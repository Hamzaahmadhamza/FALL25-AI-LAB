# %% [markdown]
# # Lab Task 10 (pt2-Task-09)

# %%
import pandas as pd
import numpy as np
dataset = pd.read_csv('Employee_Salary_Dataset.csv')

# %%
print("Total rows:", dataset.shape[0])
print("Total columns:", dataset.shape[1])
# Out:
# Total rows: 35
# Total columns: 5

# %%
print(np.sum(pd.isnull(dataset)))
print()
# Out:
# ID                  0
# Experience_Years    0
# Age                 0
# Gender              0
# Salary              0
# dtype: int64
# C:\Users\MIT\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\numpy\_core\fromnumeric.py:84: FutureWarning: The behavior of DataFrame.sum with axis=None is deprecated, in a future version this will reduce over both axes and return a scalar. To retain the old behavior, pass axis=0 (or do not pass axis)
#   return reduction(axis=axis, out=out, **passkwargs)

# %%
column_name = "Department"
if column_name in dataset.columns:
    print(data[column_name].unique())
else:
    print("The column does not exist.")
print()
# Out:
# The column does not exist.

# %%
for col in dataset.columns:
    if dataset[col].dtype == 'object':
        dataset[col] = dataset[col].fillna(dataset[col].mode()[0])
    else:
        dataset[col] = dataset[col].fillna(dataset[col].median())
print("Missing values filled.\n")
# Out:
# Missing values filled.

# %%
for col in dataset.columns:
    if dataset[col].dtype != 'object':
        dataset[col] = dataset[col].astype(np.int64)

print("Numeric conversion completed.\n")
# Out:
# Numeric conversion completed.

# %%
if "id" in dataset.columns:
    dataset.drop("id", axis=1, inplace=True)
    print("Dropped column: id\n")
else:
    print("No unnecessary column found.\n")
# Out:
# No unnecessary column found.

# %%
print(dataset.dtypes, "\n")
# Out:
# ID                   int64
# Experience_Years     int64
# Age                  int64
# Gender              object
# Salary               int64
# dtype: object

# %%
X = dataset.iloc[:, :-1]
Y = dataset.iloc[:, -1]

print("X shape:", X.shape)
print("Y shape:", Y.shape, "\n")
# Out:
# X shape: (35, 4)
# Y shape: (35,)

# %%
cat_columns = X.select_dtypes(['object']).columns
X[cat_columns] = X[cat_columns].apply(lambda col: pd.factorize(col)[0])

print("Encoding completed.\n")
# Out:
# Encoding completed.

# %%
print("Final preview of processed dataset:")
print(X.head())
# Out:
# Final preview of processed dataset:
#    ID  Experience_Years  Age  Gender
# 0   1                 5   28       0
# 1   2                 1   21       1
# 2   3                 3   23       0
# 3   4                 2   22       1
# 4   5                 1   17       1
